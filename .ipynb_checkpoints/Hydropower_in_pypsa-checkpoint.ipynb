# %% [markdown]
# # **Hydropower constraint in PyPSA with Linopy**

# %% [markdown]
# This notebook uses a toy PyPSA model to showcase how hydropower dispatch can be bounded by the historical hydro operation. With this approach, we avoid that the bulk hydropower reservoir is operated in a too ideal manner caused by the year-ahead perfect foresight assumed in the model.
#
# The toy model is a copper plate representation of the Norwegian electricity system. Hydropower capacity is included exogenously (Norway has a capacity of [37.7 GW](https://energifaktanorge.no/en/norsk-energiforsyning/kraftproduksjon/)) while wind and solar generation capacity are included endogenously, i.e., they are subject to optimization. Furthermore, as an electricity storage option, we make Li-Ion batteries available to be invested in.
#
# Capital costs used in this toy model do not represent real values but are solely used as exemplary data. The same applies to the considered scenario. The scenario is realized by assuming that the electricity load is increased by a factor 2 to force a capacity expansion. Secondly, we force the system to rely heavily on solar to introduce a large mismatch during winter. In this period, the perfect foresight of the model entails that hydropower reservoirs are discharged heavily, while the dispatch during summer is very low. To ensure that we do not interrupt with other non-energy system phenomena, e.g., water accesability and ecosystem flow continuity requirements, we need to constrain the dispatch.
#
# For a robust PyPSA-Eur implementation, the following things need to be made:
# - Write the query code that fetches the ENTSO-E dispatch data (currently, this was manually downloaded and the recent years are for this reason not included)
# - Create a Github repo that stores all historical dispatch data (it would be inconvenient if this was added directly to the PyPSA-Eur repo)
# - Extend this jupyter notebook to account for multiple nodes within a country, i.e., historical data needs to be split and scaled (according to population/demand?)
#
# The capacity factors of solar and wind are acquired from the course in [Renewable Energy Systems](https://github.com/martavp/RES_project) taught by Marta Victoria.

# %% [markdown]
# Import useful modules:

# %%
import pypsa
import pandas as pd
import numpy as np
import xarray as xr
import importlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import yaml
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# The following lines ensure continuous reloading of functions which is convenient in the editing stage:

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import functions:

# %%
from plotting import plot_layout, plot_historical_dispatch, plot_hydro_operation, plot_electricity_supply, plot_total_electricity_supply
from investment import annuity,build_base_network, solve_network

# %% [markdown]
# Standardize figure layout:

# %%
fs = 18
plot_layout(fs)
tech_colors_path = 'tech_colors.yaml'
with open(tech_colors_path) as file:
    tech_colors = yaml.safe_load(file)['tech_colors']

# %% [markdown]
# Pick a country (here, we consider Norway due to their high share of hydropower):

# %%
country = 'NOR'

country_iso_alpha2 = {'NOR':'NO'} # country codes
long_country_name = {'NOR':'Norway',
                    'SWE':'Sweden',
                    'AUT':'Austria'}
hydro_cap = {'NOR':37732} # the aggregate power capacity of each countries
hydro_max_hours = {'NOR':1129.7} # the max hours (duration), which implicitly defines the energy capacity, of the hydro reservoir

# %% [markdown]
# # **Historical inflow**

# %%
inflow_values = pd.read_csv('data/inflow/Hydro_inflow_' + country_iso_alpha2[country] + '.csv', sep=',', index_col=0)
hydro_dates = pd.date_range('1/1/2003','31/12/2012',freq='d')
inflow_series = pd.Series(index=hydro_dates,
                          data=inflow_values['Inflow [GWh]'].values)*1e3 # convert GWh to MWh
inflow_series_hourly = inflow_series.resample(rule='h').mean().interpolate(method='linear')/24

# %% [markdown]
# Available years:

# %%
print('Historical inflow years: ', list(inflow_series_hourly.index.year.unique()))
# Out:
# Historical inflow years:  [2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012]

# %% [markdown]
# Pick one of the year contained in the above list:

# %%
hydro_year = 2011
inflow_series_hourly_year = inflow_series_hourly.loc[inflow_series_hourly.index[inflow_series_hourly.index.year == hydro_year]]

# %% [markdown]
# # **Historical dispatch**

# %% [markdown]
# The question is, do we want to limit the hourly power generation or the aggregate energy production? We test this in the following.

# %% [markdown]
# Read historical data on hydro reservoir dispatch:

# %%
historical_dispatch = pd.read_csv('ENTSOE_data/dispatch_' + long_country_name[country] + '_2015-2018.csv',index_col=0)
historical_dispatch.index = pd.to_datetime(historical_dispatch.index)
df = pd.DataFrame(index=pd.date_range('1/1/2015','1/1/2016',freq='h',closed='left'))

# %% [markdown]
# Split data by year:

# %%
df1 = pd.DataFrame(historical_dispatch)
df1['year'] = df1.index.year
for year in df1.index.year.unique():
    df1_year = df1.query('year == @year')
    df1_year = df1_year[~df1_year.index.duplicated(keep='first')]
    
    if (year % 4 == 0) and (year % 100 != 0): # leap year    
        day_29 = df1_year.index.day == 29
        feb_29 = df1_year[day_29][df1_year[day_29].index.month == 2]
        df1_year = df1_year.drop(index=feb_29.index)
    
    df[year] = df1_year.disp.values

# %% [markdown]
# ## Hourly dispatch

# %%
df_min = df.min(axis=1)
df_max = df.max(axis=1)

fig, ax = plt.subplots()
x = df_min.index
y1 = df_min
y2 = df_max
ax.fill_between(x,y1,y2,alpha=0.5,label='Historical (2015-2018)')

ax.set_xlim(min(x),max(x))
ax.legend()
ax.set_ylabel('Hourly hydro dispatch [GWh]')

fmt = mdates.DateFormatter('%b')
ax.xaxis.set_major_formatter(fmt);

# %% [markdown]
# We do see a seasonal trend. However, note that peak dispatch power is observed troughout the year. Althouh low dispatch is observed on average during summer, hours with full utilization of the hydropower capacity is still observed in this period. From this observation, we learn that **we should not constrain the hourly dispatch**.

# %% [markdown]
# We can check this for other countries (to do so, uncomment the below line), here exemplified with Sweden:

# %%
# plot_historical_dispatch('SWE',long_country_name,freq='h')

# %% [markdown]
# ## Monthly aggregate dispatch

# %% [markdown]
# Instead of looking at hourly dispatch, let's consider the monthly aggregate. Here, we illustrate the historical band of the dispatch based on monthly aggregate:

# %%
df_min = df.min(axis=1)
df_max = df.max(axis=1)

fig, ax = plt.subplots()
x = df_min.resample('m').sum().index - pd.Timedelta('15d')
y1 = df_min.resample('m').sum()/(df.mean(axis=1).resample('m').sum().sum())
y2 = df_max.resample('m').sum()/(df.mean(axis=1).resample('m').sum().sum())

ax.fill_between(x,y1,y2,alpha=0.5,label='Historical (2015-2018)')
ax.set_xlim(min(x),max(x))
ax.legend()
ax.set_ylabel('Monthly hydro dispatch as a \n fraction of the annual dispatch [-]')

fmt = mdates.DateFormatter('%b')
ax.xaxis.set_major_formatter(fmt);

# %% [markdown]
# By using the monthly aggregate, we can constrain the hydropower more realistically to retain the historical seasonality - and we still allow hours with peak power production during summer.

# %% [markdown]
# # **Investment optimization**

# %% [markdown]
# ## Create network

# %% [markdown]
# Initialize network:

# %%
n = pypsa.Network()

# %% [markdown]
# Add buses (here, an electricity bus):

# %%
n.add("Bus","electricity bus")

# %% [markdown]
# Add carriers:

# %%
carriers = ['wind','solar','hydro','battery']
n.madd("Carrier",carriers);

# %% [markdown]
# Add time snapshots:

# %%
hours = pd.date_range('2015-01-01T00:00Z','2015-12-31T23:00Z', freq='H')
n.set_snapshots(hours)

# %% [markdown]
# Add load:

# %% [markdown]
# Let's assume the case at which Norway increses its electricity demand by a factor of 2. Otherwise, no capacity expansion would take place since hydro can cover all the load.

# %%
load_csv = 'data/electricity_demand.csv'
load = pd.read_csv(load_csv, sep=';', index_col=0)
load.index = pd.to_datetime(load.index)
load_scale_up = 2
n.add('Load', # pypsa component
      'el_load', # name
      bus = 'electricity bus', # bus name
      p_set = load[country]*load_scale_up
     )

# %% [markdown]
# # Add generators and storage

# %% [markdown]
# Let's force the system to have more solar than wind. In this way, without a hydropower constraint, the system chooses to have high hydro dispatch during winter to overcome the concurrently low availability of solar energy. As mentioned in the introduction, this does not represent any real scenario but is more a "model trick" to showcase an example.

# %%
p_nom_wind  = 0
p_nom_solar = 0
p_nom_max_wind = 10e5 # 10e3
p_nom_max_solar = 10e5

# %% [markdown]
# ## *Wind* (added endogenously)

# %% [markdown]
# Capacity factors:

# %%
df_onshorewind = pd.read_csv('data/onshore_wind_1979-2017.csv', sep=';', index_col=0)
df_onshorewind.index = pd.to_datetime(df_onshorewind.index)
CF_wind = df_onshorewind[country][[hour.strftime("%Y-%m-%dT%H:%M:%SZ") for hour in n.snapshots]]

# %% [markdown]
# Add generator:

# %%
n.add('Generator',
      'wind',
      bus='electricity bus',
      carrier='wind',
      p_nom = p_nom_wind,
      p_nom_extendable=True,
      p_nom_max=p_nom_max_wind, # maximum capacity can be limited due to environmental constraints
      capital_cost=1e6*annuity(30,0.07),
      marginal_cost=0.015,
      p_max_pu=CF_wind,
     )

# %%
#n.add('Generator',
#      'wind2',
#      bus='electricity bus',
#      carrier='wind',
#      p_nom = 1e5,
#      p_nom_extendable=False,
#      p_nom_max=p_nom_max_wind, # maximum capacity can be limited due to environmental constraints
#      capital_cost=1e6*annuity(30,0.07),
#      marginal_cost=0.015,
#      p_max_pu=CF_wind,
#     )

# %% [markdown]
# ## *Solar* (added endogenously)

# %% [markdown]
# Capacity factors:

# %%
df_solar = pd.read_csv('data/pv_optimal.csv', sep=';', index_col=0)
df_solar.index = pd.to_datetime(df_solar.index)
CF_solar = df_solar[country][[hour.strftime("%Y-%m-%dT%H:%M:%SZ") for hour in n.snapshots]]

# %% [markdown]
# Add generator:

# %%
n.add('Generator',
      'solar',
      bus='electricity bus',
      carrier='solar',
      p_nom = p_nom_solar,
      p_nom_extendable=True,
      p_nom_max=p_nom_max_solar, # maximum capacity can be limited due to environmental constraints
      capital_cost=1e5*annuity(30,0.07),
      marginal_cost=0.01,
      p_max_pu=CF_solar,
     )

# %% [markdown]
# ## *Hydro reservoir* (added exogenously)

# %%
inflow_series_hourly_year.index = n.snapshots
hydro_inflow = inflow_series_hourly_year

# %%
n.add('StorageUnit',
      'hydro',
      bus='electricity bus',
      carrier = 'hydro',
      p_nom_extendable=False,
      p_nom=hydro_cap[country],
      inflow=hydro_inflow,
      max_hours=hydro_max_hours[country],
      capital_cost=10e6*annuity(30,0.07),
      marginal_cost=0.,
      p_max_pu=1, 
      p_min_pu=0, 
      efficiency_dispatch=0.9,
      efficiency_store=0.0, # you can't store electricity in this item
      cyclic_state_of_charge=True,
     )

# %% [markdown]
# ## *Li-Ion battery* (added endogenously)

# %%
n.add('StorageUnit',
      'battery',
      bus='electricity bus',
      carrier = 'battery',
      p_nom_extendable=True,
      capital_cost=1e6*annuity(30,0.07),
      max_hours=6,
      efficiency_store=0.95,
      efficiency_dispatch=0.95,
      cyclic_state_of_charge=True
     )

# %% [markdown]
# # **Results for an <u> unconstrained </u> hydro operation**

# %% [markdown]
# It is a good idea to check if the network is built consistently. This can be done with the PyPSA function "consistency_check". From the PyPSA documentation:
#
# "Checks the network for consistency; e.g. that all components are connected to existing buses and that no impedances are singular.
#
# Prints warnings if anything is potentially inconsistent."

# %%
n.consistency_check()

# %% [markdown]
# No output means that no inconsistencies are present. Them, we can proceed solving the network:

# %%
solve_network(n)
# Out:
# INFO:investment:No expandable lines found. Skipping iterative solving.
# INFO:linopy.model: Solve linear problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - threads: 4
#  - method: 2
#  - crossover: 0
#  - BarConvTol: 1e-06
#  - Seed: 123
#  - AggFill: 0
#  - PreDual: 0
#  - GURO_PAR_BARDENSETHRESH: 200
#  - seed: 10
# Writing constraints.: 100%|████████████████████████████████████████████████████████████| 23/23 [00:02<00:00,  8.67it/s]
# Writing variables.: 100%|████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 18.38it/s]
# Read LP format model from file C:\Users\au485969\AppData\Local\Temp\linopy-problem-i2728vk0.lp
# Reading time = 1.15 seconds
# obj: 183966 rows, 87604 columns, 337894 nonzeros
# Set parameter Threads to value 4
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Set parameter BarConvTol to value 1e-06
# Set parameter Seed to value 123
# Set parameter AggFill to value 0
# Set parameter PreDual to value 0
# Set parameter GURO_PAR_BARDENSETHRESH to value 200
# Set parameter Seed to value 10
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10510U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 4 threads
#
# Optimize a model with 183966 rows, 87604 columns and 337894 nonzeros
# Model fingerprint: 0xccc98ffe
# Coefficient statistics:
#   Matrix range     [1e-03, 6e+00]
#   Objective range  [1e-02, 8e+04]
#   Bounds range     [4e+03, 9e+07]
#   RHS range        [3e+03, 4e+07]
# Presolve removed 117636 rows and 12512 columns
# Presolve time: 0.32s
# Presolved: 66330 rows, 75092 columns, 207747 nonzeros
# Ordering time: 0.07s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.589e+05
#  Factor NZ  : 8.285e+05 (roughly 60 MB of memory)
#  Factor Ops : 1.079e+07 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.96822295e+11 -2.19123582e+15  8.65e+09 1.95e+01  2.21e+10     1s
#    1   4.51687362e+11 -5.73239954e+14  6.18e+09 8.16e+02  7.45e+09     1s
#    2   4.02804859e+11 -1.52986831e+14  4.89e+09 1.84e+02  3.56e+09     1s
#    3   3.65516552e+11 -3.30247277e+13  8.79e+08 2.91e+01  6.64e+08     1s
#    4   3.19322756e+11 -8.53819112e+12  4.83e+07 2.90e+00  8.07e+07     1s
#    5   1.89600235e+11 -1.88321509e+12  1.14e+06 4.18e-01  1.42e+07     1s
#    6   1.38942005e+11 -1.27475799e+12  5.93e+05 7.25e-02  9.56e+06     1s
#    7   1.10767611e+11 -7.29479014e+11  2.46e+05 1.02e-12  5.65e+06     1s
#    8   1.02279244e+11 -4.12411151e+11  1.91e+05 7.39e-13  3.45e+06     2s
#    9   5.50995024e+10 -1.07060785e+11  3.06e+04 4.26e-13  1.08e+06     2s
#   10   2.31566066e+10 -3.10007092e+10  1.27e+04 1.42e-13  3.61e+05     2s
#   11   7.29726736e+09 -1.24349530e+10  3.62e+03 6.04e-14  1.31e+05     2s
#   12   4.91884816e+09 -6.74764100e+09  2.32e+03 3.38e-14  7.77e+04     2s
#   13   2.52985678e+09 -2.82814390e+09  9.92e+02 6.01e-11  3.57e+04     2s
#   14   5.72043456e+08 -7.12346111e+08  1.37e-01 6.10e-10  8.55e+03     2s
#   15   6.62876053e+07 -2.29937196e+08  2.86e-02 3.87e-10  1.97e+03     2s
#   16  -2.25559878e+07 -9.90205696e+07  8.51e-03 9.55e-09  5.09e+02     2s
#   17  -8.62890253e+07 -9.05920300e+07  1.83e-05 1.61e-06  2.89e+01     3s
#   18  -8.66871183e+07 -8.68649370e+07  1.19e-06 9.55e-07  1.22e+00     3s
#   19  -8.67169880e+07 -8.67182883e+07  2.21e-07 1.27e-08  8.96e-03     3s
#   20  -8.67170193e+07 -8.67170193e+07  1.07e-08 6.47e-10  2.25e-07     3s
#
# Barrier solved model in 20 iterations and 2.91 seconds (0.71 work units)
# Optimal objective -8.67170193e+07
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 87604 primals, 183966 duals
# Objective: -8.67e+07
# Solver model: available
# Solver message: 2
# PyPSA Network
# Components:
#  - Bus: 1
#  - Carrier: 4
#  - Generator: 3
#  - Load: 1
#  - StorageUnit: 2
# Snapshots: 8760

# %%
model_monthly_dispatch = n.storage_units_t.p['hydro'].resample('m').sum()/1e3
historical_monthly_dispatch_min = df.resample('m').sum().min(axis=1)
historical_monthly_dispatch_max = df.resample('m').sum().max(axis=1)

# %% [markdown]
# Hydropower operation:

# %%
plot_hydro_operation(n,
                     df,
                     hydro_inflow,
                     freq='m'
                    )

# %% [markdown]
# At a high share of solar, the modeled dispatch exceeds the historical region. This is in line with the findings in [Gøtske and Victoria (2022)](https://doi.org/10.1016/j.isci.2021.102999).

# %% [markdown]
# Wind and solar power supply + battery balance:

# %%
plot_electricity_supply(n,
                   tech_colors,
                   freq='w')

# %% [markdown]
# Annual electricity supply:

# %%
plot_total_electricity_supply(n,tech_colors)

# %%
n.model.variables
# Out:
# linopy.model.Variables
# ----------------------
#
# Dimensions:                      (Generator-ext: 2, StorageUnit-ext: 1,
#                                   snapshot: 8760, Generator: 3, StorageUnit: 2)
# Coordinates:
#   * Generator-ext                (Generator-ext) object 'wind' 'solar'
#   * StorageUnit-ext              (StorageUnit-ext) object 'battery'
#   * snapshot                     (snapshot) object 1420070400000000000 ... 14...
#   * Generator                    (Generator) object 'wind' 'solar' 'wind2'
#   * StorageUnit                  (StorageUnit) object 'hydro' 'battery'
#
# Labels:
#     Generator-p_nom              (Generator-ext) int32 0 1
#     StorageUnit-p_nom            (StorageUnit-ext) int32 2
#     Generator-p                  (snapshot, Generator) int32 3 4 ... 26281 26282
#     StorageUnit-p_dispatch       (snapshot, StorageUnit) int32 26283 ... 43802
#     StorageUnit-p_store          (snapshot, StorageUnit) int32 43803 ... 61322
#     StorageUnit-state_of_charge  (snapshot, StorageUnit) int32 61323 ... 78842
#     StorageUnit-spill            (snapshot, StorageUnit) int32 78843 -1 ... -1
#     objective_constant           int32 96363
#
# Lower bounds:
#     Generator-p_nom              (Generator-ext) float64 -inf -inf
#     StorageUnit-p_nom            (StorageUnit-ext) float64 -inf
#     Generator-p                  (snapshot, Generator) float64 -inf ... -inf
#     StorageUnit-p_dispatch       (snapshot, StorageUnit) float64 -inf ... -inf
#     StorageUnit-p_store          (snapshot, StorageUnit) float64 -inf ... -inf
#     StorageUnit-state_of_charge  (snapshot, StorageUnit) float64 -inf ... -inf
#     StorageUnit-spill            int32 0
#     objective_constant           float64 8.865e+07
#
# Upper bounds:
#     Generator-p_nom              (Generator-ext) float64 inf inf
#     StorageUnit-p_nom            (StorageUnit-ext) float64 inf
#     Generator-p                  (snapshot, Generator) float64 inf inf ... inf
#     StorageUnit-p_dispatch       (snapshot, StorageUnit) float64 inf inf ... inf
#     StorageUnit-p_store          (snapshot, StorageUnit) float64 inf inf ... inf
#     StorageUnit-state_of_charge  (snapshot, StorageUnit) float64 inf inf ... inf
#     StorageUnit-spill            (snapshot, StorageUnit) float64 4.505e+03 .....
#     objective_constant           float64 8.865e+07

# %%
n.generators.p_nom['wind'].sum()
# Out:
# 0.0

# %%
n.model.variables["Generator-p_nom"] # only "Generator-ext" (extendable generators appear) which makes sense since these are the only ones that we can limit capacity-wise.
# Out:
# Variable (Generator-ext: 2)
# ---------------------------
# [wind]:  Generator-p_nom[wind]  ∈ [-inf, inf]
# [solar]: Generator-p_nom[solar] ∈ [-inf, inf]

# %%
n.model.variables["Generator-p_nom"].sel({"Generator-ext":'wind'}).sum()
# Out:
# LinearExpression:
# -----------------
# 1.0 Generator-p_nom[wind]

# %%
m.variables["Generator-p_nom"].sel({"Generator-ext":'wind'})
# Out:
# Variable
# ---------
# [wind]: Generator-p_nom[wind] ∈ [-inf, inf]

# %%
m.variables["Generator-p_nom"]
# Out:
# Variable (Generator-ext: 2)
# ---------------------------
# [wind]:  Generator-p_nom[wind]  ∈ [-inf, inf]
# [solar]: Generator-p_nom[solar] ∈ [-inf, inf]

# %%
# inspired by Leon's paper
n.local_constraints = pd.DataFrame()
n.local_constraints_t = {}
tmp = n.components.GlobalConstraint.copy()
tmp.update({'list_name':'local_constraints'})
n.components.LocalConstraints = tmp
n.all_components.add('LocalConstraints')

# %%
from pypsa.linopt import get_var

# %% [markdown]
# you could also look at [the Linopy compatibility function](https://pypsa.readthedocs.io/en/stable/examples/optimization-with-linopy-migrate-extra-functionalities.html) which allows the "old" constraint syntac to be migrated to Linopy.

# %% [markdown]
# Get all batteries:

# %%
m.variables['StorageUnit-p_nom'].sel({"StorageUnit-ext":'battery'})
# Out:
# Variable
# ---------
# [battery]: StorageUnit-p_nom[battery] ∈ [-inf, inf]

# %%
kwargs = {'snapshot':30*24}
m.variables['Generator-p'].sel(Generator = 'wind').rolling_sum(**kwargs)
# Out:
# LinearExpression (snapshot: 8760):
# ----------------------------------
# [2015-01-01 00:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind]
# [2015-01-01 01:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind]
# [2015-01-01 02:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 02:00:00+00:00, wind]
# [2015-01-01 03:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 02:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 03:00:00+00:00, wind]
# [2015-01-01 04:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 02:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 03:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 04:00:00+00:00, wind]
# [2015-01-01 05:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 02:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 03:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 04:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 05:00:00+00:00, wind]
# [2015-01-01 06:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 02:00:00+00:00, wind] ... 1.0 Generator-p[2015-01-01 04:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 05:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 06:00:00+00:00, wind]
# 		...
# [2015-12-31 17:00:00+00:00]: 1.0 Generator-p[2015-12-01 18:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 19:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 20:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 15:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 16:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 17:00:00+00:00, wind]
# [2015-12-31 18:00:00+00:00]: 1.0 Generator-p[2015-12-01 19:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 20:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 21:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 16:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 17:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 18:00:00+00:00, wind]
# [2015-12-31 19:00:00+00:00]: 1.0 Generator-p[2015-12-01 20:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 21:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 22:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 17:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 18:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 19:00:00+00:00, wind]
# [2015-12-31 20:00:00+00:00]: 1.0 Generator-p[2015-12-01 21:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 22:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 23:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 18:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 19:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 20:00:00+00:00, wind]
# [2015-12-31 21:00:00+00:00]: 1.0 Generator-p[2015-12-01 22:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 23:00:00+00:00, wind] + 1.0 Generator-p[2015-12-02 00:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 19:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 20:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 21:00:00+00:00, wind]
# [2015-12-31 22:00:00+00:00]: 1.0 Generator-p[2015-12-01 23:00:00+00:00, wind] + 1.0 Generator-p[2015-12-02 00:00:00+00:00, wind] + 1.0 Generator-p[2015-12-02 01:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 20:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 21:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 22:00:00+00:00, wind]
# [2015-12-31 23:00:00+00:00]: 1.0 Generator-p[2015-12-02 00:00:00+00:00, wind] + 1.0 Generator-p[2015-12-02 01:00:00+00:00, wind] + 1.0 Generator-p[2015-12-02 02:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 21:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 22:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 23:00:00+00:00, wind]

# %%
n.model.variables
# Out:
# linopy.model.Variables
# ----------------------
#
# Dimensions:                      (Generator-ext: 2, StorageUnit-ext: 1,
#                                   snapshot: 8760, Generator: 2, StorageUnit: 2)
# Coordinates:
#   * Generator-ext                (Generator-ext) object 'wind' 'solar'
#   * StorageUnit-ext              (StorageUnit-ext) object 'battery'
#   * snapshot                     (snapshot) object 1420070400000000000 ... 14...
#   * Generator                    (Generator) object 'wind' 'solar'
#   * StorageUnit                  (StorageUnit) object 'hydro' 'battery'
#
# Labels:
#     Generator-p_nom              (Generator-ext) int32 0 1
#     StorageUnit-p_nom            (StorageUnit-ext) int32 2
#     Generator-p                  (snapshot, Generator) int32 3 4 ... 17521 17522
#     StorageUnit-p_dispatch       (snapshot, StorageUnit) int32 17523 ... 35042
#     StorageUnit-p_store          (snapshot, StorageUnit) int32 35043 ... 52562
#     StorageUnit-state_of_charge  (snapshot, StorageUnit) int32 52563 ... 70082
#     StorageUnit-spill            (snapshot, StorageUnit) int32 70083 -1 ... -1
#
# Lower bounds:
#     Generator-p_nom              (Generator-ext) float64 -inf -inf
#     StorageUnit-p_nom            (StorageUnit-ext) float64 -inf
#     Generator-p                  (snapshot, Generator) float64 -inf ... -inf
#     StorageUnit-p_dispatch       (snapshot, StorageUnit) float64 -inf ... -inf
#     StorageUnit-p_store          (snapshot, StorageUnit) float64 -inf ... -inf
#     StorageUnit-state_of_charge  (snapshot, StorageUnit) float64 -inf ... -inf
#     StorageUnit-spill            int32 0
#
# Upper bounds:
#     Generator-p_nom              (Generator-ext) float64 inf inf
#     StorageUnit-p_nom            (StorageUnit-ext) float64 inf
#     Generator-p                  (snapshot, Generator) float64 inf inf ... inf
#     StorageUnit-p_dispatch       (snapshot, StorageUnit) float64 inf inf ... inf
#     StorageUnit-p_store          (snapshot, StorageUnit) float64 inf inf ... inf
#     StorageUnit-state_of_charge  (snapshot, StorageUnit) float64 inf inf ... inf
#     StorageUnit-spill            (snapshot, StorageUnit) float64 4.505e+03 .....

# %% [markdown]
# # **Results for a <u> constrained </u> hydro operation**

# %% [markdown]
# The following 'build_base_network' repeats the commands in the above, i.e., build network, add generators and storage units, etc.:

# %%
n = build_base_network(country,
                       load_csv,
                       load_scale_up,
                       CF_wind,
                       p_nom_wind,
                       p_nom_max_wind,
                       CF_solar,
                       p_nom_solar,
                       p_nom_max_solar,
                       carriers_list=['wind','solar','battery'])

# %%
# Let's define the upper and lower bound:
#df_min_2 = df_min.resample('m').min() # gives you the hourly minimum within the considered month
#df_min_2_hourly = df_min_2.resample(rule='h').mean().interpolate(method='linear')

# %% [markdown]
# We also import the reservoir fill level to add initial fill level in each reservoir:

# %%
n.generators.p_nom['wind'].sum()
# Out:
# 0.0

# %%
#reservoir_fill_level = pd.read_csv('ENTSOE_data/reservoir_fill_level_Norway.csv')
#reservoir_fill_level.columns = ['week','2015','2016','2017','2018']
#df_res_level = reservoir_fill_level.drop(columns=['week']).astype(float)
#df_res_level = (df_res_level.fillna(method='ffill') + df_res_level.fillna(method='bfill'))/2
#df_res_level = df_res_level.drop(index=52)

# %%
#all_max = df.max().max()
#df_min = df.min(axis=1)
#df_max = df.max(axis=1)

#hydro_min_constraint = df_min/all_max*0.2
#hydro_max_constraint = df_max/all_max

# %%
#hydro_min_constraint.index = n.snapshots
#hydro_max_constraint.index = n.snapshots

# %%
#min_df = pd.Series(index=n.snapshots,data=[0.]*8760)
#max_df = pd.Series(index=n.snapshots,data=[1.]*8760)

# %%
n.add('StorageUnit',
      'hydro',
      bus='electricity bus',
      carrier = 'hydro',
      p_nom_extendable=False,
      p_nom=hydro_cap[country],
      inflow=hydro_inflow,
      max_hours=hydro_max_hours[country],
      capital_cost=10e6*annuity(30,0.07),
      marginal_cost=0.,
      p_max_pu=1, 
      p_min_pu=0,
      efficiency_dispatch=0.9,
      efficiency_store=0.0, # you can't store electricity in this item
      cyclic_state_of_charge=True,
      #state_of_charge_initial = df_res_level.loc[0].min()
     )

# %% [markdown]
# Now we proceed with accesing the linopy interface to add the constraints. First, we create the model interface:

# %%
m = n.optimize.create_model()

# %% [markdown]
# From this, we can find variables and constraint definitions.

# %%
lhs
# Out:
# LinearExpression:
# -----------------
# 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 02:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 21:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 22:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 23:00:00+00:00, wind]

# %%
from investment import rolling_sum

# %%
m_wind_data = m.variables["Generator-p"].sel(Generator='wind').data

# %%
m_wind_data['snapshot'] = pd.DatetimeIndex(m_wind_data['snapshot'].values)

# %%
m_wind_data.resample(snapshot='m').sum()
# Out:
# <xarray.DataArray 'Generator-p' (snapshot: 12)>
# array([  555024,  1452864,  2662032,  3630240,  4840464,  5738400,
#         7018896,  8125968,  8917920, 10304400, 11026080, 12482832])
# Coordinates:
#     Generator  <U4 'wind'
#   * snapshot   (snapshot) datetime64[ns] 2015-01-31 2015-02-28 ... 2015-12-31
# Attributes:
#     binary:   False
#     integer:  False

# %%
xr_data = m.variables["StorageUnit-p_dispatch"].sel(StorageUnit='hydro').data
xr_data['snapshot'] = pd.DatetimeIndex(xr_data['snapshot'].values)
lhs = xr_data.resample(snapshot='m').sum()

# %%
rhs = np.arange(8760) # <----- The current issue is to have the "rhs" as an array

# %% [markdown]
# If we were allowed to have "rhs" as a vector, this would be easily solved.

# %%
lhs
# Out:
# LinearExpression (snapshot: 8760):
# ----------------------------------
# [2015-01-01 00:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind]
# [2015-01-01 01:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind]
# [2015-01-01 02:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 02:00:00+00:00, wind]
# [2015-01-01 03:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 02:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 03:00:00+00:00, wind]
# [2015-01-01 04:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 02:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 03:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 04:00:00+00:00, wind]
# [2015-01-01 05:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 02:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 03:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 04:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 05:00:00+00:00, wind]
# [2015-01-01 06:00:00+00:00]: 1.0 Generator-p[2015-01-01 00:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 01:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 02:00:00+00:00, wind] ... 1.0 Generator-p[2015-01-01 04:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 05:00:00+00:00, wind] + 1.0 Generator-p[2015-01-01 06:00:00+00:00, wind]
# 		...
# [2015-12-31 17:00:00+00:00]: 1.0 Generator-p[2015-12-01 18:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 19:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 20:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 15:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 16:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 17:00:00+00:00, wind]
# [2015-12-31 18:00:00+00:00]: 1.0 Generator-p[2015-12-01 19:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 20:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 21:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 16:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 17:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 18:00:00+00:00, wind]
# [2015-12-31 19:00:00+00:00]: 1.0 Generator-p[2015-12-01 20:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 21:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 22:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 17:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 18:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 19:00:00+00:00, wind]
# [2015-12-31 20:00:00+00:00]: 1.0 Generator-p[2015-12-01 21:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 22:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 23:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 18:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 19:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 20:00:00+00:00, wind]
# [2015-12-31 21:00:00+00:00]: 1.0 Generator-p[2015-12-01 22:00:00+00:00, wind] + 1.0 Generator-p[2015-12-01 23:00:00+00:00, wind] + 1.0 Generator-p[2015-12-02 00:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 19:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 20:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 21:00:00+00:00, wind]
# [2015-12-31 22:00:00+00:00]: 1.0 Generator-p[2015-12-01 23:00:00+00:00, wind] + 1.0 Generator-p[2015-12-02 00:00:00+00:00, wind] + 1.0 Generator-p[2015-12-02 01:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 20:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 21:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 22:00:00+00:00, wind]
# [2015-12-31 23:00:00+00:00]: 1.0 Generator-p[2015-12-02 00:00:00+00:00, wind] + 1.0 Generator-p[2015-12-02 01:00:00+00:00, wind] + 1.0 Generator-p[2015-12-02 02:00:00+00:00, wind] ... 1.0 Generator-p[2015-12-31 21:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 22:00:00+00:00, wind] + 1.0 Generator-p[2015-12-31 23:00:00+00:00, wind]

# %%
kwargs = {'snapshot':30*24}
lhs = m.variables["Generator-p"].sel(Generator='wind').rolling_sum(**kwargs)
m.add_constraints(lhs <= rhs, name="hydro seasonality constraint3")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[221], line 3
#       1 kwargs = {'snapshot':30*24}
#       2 lhs = m.variables["Generator-p"].sel(Generator='wind').rolling_sum(**kwargs)
# ----> 3 m.add_constraints(lhs <= rhs, name="hydro seasonality constraint3")
#
# File ~\Anaconda3\envs\pypsa-eur\lib\site-packages\linopy\model.py:596, in Model.add_constraints(self, lhs, sign, rhs, name, coords, mask)
#     593 if labels is None:
#     594     labels = (lhs.vars.chunk() + rhs).sum("_term")
# --> 596 self.check_force_dim_names(labels)
#     598 start = self._cCounter
#     599 labels.data = np.arange(start, start + labels.size).reshape(labels.shape)
#
# File ~\Anaconda3\envs\pypsa-eur\lib\site-packages\linopy\model.py:334, in Model.check_force_dim_names(self, ds)
#     330 contains_default_dims = any(
#     331     bool(re.match(r"dim_[0-9]+", dim)) for dim in ds.dims
#     332 )
#     333 if self.force_dim_names and contains_default_dims:
# --> 334     raise ValueError(
#     335         "Added data contains non-customized dimension names. This is not "
#     336         "allowed when setting `force_dim_names` to True."
#     337     )
#     338 else:
#     339     return
#
# ValueError: Added data contains non-customized dimension names. This is not allowed when setting `force_dim_names` to True.

# %%
xr_data = m.variables["StorageUnit-p_dispatch"].sel(StorageUnit='hydro').data
xr_data['snapshot'] = pd.DatetimeIndex(xr_data['snapshot'].values)
lhs = xr_data.resample(snapshot='m').sum()

# %%
#buses = n.generators.bus.to_xarray()

# %%
#storage_carriers = n.storage_units.carrier.to_xarray()

# %%
#m.variables["StorageUnit-p_dispatch"].groupby(storage_carriers).sum().rolling_sum()

# %%
#m.variables["StorageUnit-p_dispatch"].sel(StorageUnit='hydro').sum().shape

# %%
#m.variables["Generator-p"].sel(Generator='wind').sum("snapshot")

# %%
#kwargs = {'time':10}
#m.variables["StorageUnit-p_dispatch"].sel(StorageUnit='hydro').rolling_sum(**kwargs)

# %%
# Use this information below!!!!!

# This one here 
#lhs = model.variables["Generator-p"].sel(Generator='Oil_generator').sum()
# This one here

#model.add_constraints(lhs <= oil_max_MWh*oil_conv_efficiency, name="oil total")

#IES.optimize.solve_model()

# %%
#lhs = model.variables["StorageUnit-p_dispatch"].sel(StorageUnit='hydro').sum("snapshot")

# %%
#storage_units_carriers = n.storage_units.carrier.to_xarray()
#prod_per_bus = m.variables["StorageUnit-p_dispatch"].groupby(storage_units_carriers).sum()

# %%
#m.variables["StorageUnit-p_dispatch"].groupby_sum(storage_units_carriers)

# %%
#dir(m.variables["StorageUnit-p_dispatch"])

# %%
#m.variables["StorageUnit-p_dispatch"]

# %%
#prod_per_bus

# %%
#total_demand

# %%
#m.variables["Generator-p"].groupby(buses).sum().sum("snapshot")

# %%
#m.variables['StorageUnit-p_dispatch','battery']

# %%
#m.variables["StorageUnit-state_of_charge"]

# %%
#m = n.optimize.create_model()
#sus = m.variables["StorageUnit-state_of_charge"]
#m.add_constraints(sus >= 50, name="StorageUnit-minimum_soc")

# %%
#hydro_index_bool = n.storage_units.index.str.contains("hydro")

# %%
#hydro_index = n.storage_units[hydro_index_bool].index

# %%
#type(n.model.variables['StorageUnit-p_dispatch'])

# %%
# m.constraints

# %%
n.consistency_check()

# %%
solve_network(n)
# Out:
# INFO:investment:No expandable lines found. Skipping iterative solving.
# INFO:linopy.model: Solve linear problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - threads: 4
#  - method: 2
#  - crossover: 0
#  - BarConvTol: 1e-06
#  - Seed: 123
#  - AggFill: 0
#  - PreDual: 0
#  - GURO_PAR_BARDENSETHRESH: 200
#  - seed: 10
# Writing constraints.: 100%|████████████████████████████████████████████████████████████| 21/21 [00:01<00:00, 18.27it/s]
# Writing variables.: 100%|████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 43.01it/s]
# Read LP format model from file C:\Users\au485969\AppData\Local\Temp\linopy-problem-7lptdknn.lp
# Reading time = 0.48 seconds
# obj: 166446 rows, 78843 columns, 311614 nonzeros
# Set parameter Threads to value 4
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Set parameter BarConvTol to value 1e-06
# Set parameter Seed to value 123
# Set parameter AggFill to value 0
# Set parameter PreDual to value 0
# Set parameter GURO_PAR_BARDENSETHRESH to value 200
# Set parameter Seed to value 10
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-10510U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 4 threads
#
# Optimize a model with 166446 rows, 78843 columns and 311614 nonzeros
# Model fingerprint: 0xa65336b5
# Coefficient statistics:
#   Matrix range     [1e-03, 6e+00]
#   Objective range  [1e-02, 8e+04]
#   Bounds range     [4e+03, 4e+04]
#   RHS range        [1e+03, 4e+07]
# Presolve removed 100116 rows and 12511 columns
# Presolve time: 0.15s
# Presolved: 66330 rows, 66332 columns, 198987 nonzeros
# Ordering time: 0.03s
#
# Barrier statistics:
#  Dense cols : 3
#  AA' NZ     : 1.589e+05
#  Factor NZ  : 8.293e+05 (roughly 60 MB of memory)
#  Factor Ops : 1.081e+07 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.46683813e+11 -2.18561630e+15  1.01e+10 1.64e+01  2.53e+10     0s
#    1   5.23599971e+11 -5.78892368e+14  7.18e+09 8.24e+02  8.24e+09     0s
#    2   1.61756680e+11 -2.87277008e+14  6.10e+09 3.89e+02  5.51e+09     0s
#    3   2.60033921e+11 -4.61393138e+13  1.46e+09 5.01e+01  1.09e+09     0s
#    4   2.84618582e+11 -1.31944879e+13  4.31e+08 1.02e+01  3.07e+08     1s
#    5   2.12375700e+11 -6.56114343e+12  6.60e+07 3.95e+00  8.11e+07     1s
#    6   1.83821557e+11 -3.07037903e+12  3.30e+07 1.62e+00  3.63e+07     1s
#    7   1.52398575e+11 -1.34035758e+12  1.69e+07 5.93e-01  1.59e+07     1s
#    8   7.23760106e+10 -4.01819898e+11  5.01e+06 8.91e-02  4.42e+06     1s
#    9   3.73868944e+10 -2.15532376e+11  1.93e+06 1.98e-09  2.16e+06     1s
#   10   3.51719064e+10 -1.98953915e+11  1.76e+06 1.44e-08  1.99e+06     1s
#   11   3.48877845e+10 -1.69665031e+11  1.74e+06 1.40e-08  1.75e+06     1s
#   12   3.39677915e+10 -1.62912743e+11  1.68e+06 4.42e-09  1.68e+06     1s
#   13   3.23237629e+10 -1.49846308e+11  1.57e+06 4.19e-09  1.56e+06     1s
#   14   3.06829344e+10 -1.33586246e+11  1.46e+06 9.78e-09  1.40e+06     1s
#   15   2.86430836e+10 -1.10749500e+11  1.34e+06 1.63e-09  1.19e+06     1s
#   16   2.50528712e+10 -9.17196491e+10  1.10e+06 9.31e-10  9.92e+05     1s
#   17   2.33489682e+10 -6.93336352e+10  9.92e+05 4.07e-09  7.94e+05     1s
#   18   2.24945407e+10 -6.46283700e+10  9.29e+05 8.96e-09  7.45e+05     1s
#   19   2.04152251e+10 -4.50603745e+10  7.75e+05 1.86e-09  5.63e+05     1s
#   20   2.00301031e+10 -4.21601980e+10  7.40e+05 3.49e-09  5.35e+05     1s
#   21   1.92374188e+10 -3.96034968e+10  6.82e+05 1.98e-09  5.04e+05     2s
#   22   1.88899938e+10 -3.70112568e+10  6.53e+05 4.95e-10  4.79e+05     2s
#   23   1.78781252e+10 -3.53858341e+10  5.84e+05 1.28e-09  4.52e+05     2s
#   24   1.76129815e+10 -3.06876343e+10  5.62e+05 1.86e-09  4.12e+05     2s
#   25   1.69575327e+10 -2.85507177e+10  5.11e+05 9.90e-10  3.87e+05     2s
#   26   1.64040484e+10 -2.60191231e+10  4.72e+05 6.08e-10  3.60e+05     2s
#   27   1.56921707e+10 -2.45013251e+10  4.18e+05 4.07e-09  3.38e+05     2s
#   28   1.51836483e+10 -2.16425790e+10  3.49e+05 2.50e-09  3.07e+05     2s
#   29   1.40526483e+10 -1.67361176e+10  2.75e+05 2.04e-09  2.55e+05     2s
#   30   1.32711184e+10 -1.09765312e+10  2.19e+05 3.22e-10  2.01e+05     2s
#   31   1.25003784e+10 -3.26828789e+09  1.63e+05 1.34e-10  1.32e+05     2s
#   32   1.20112772e+10 -9.76136421e+08  1.32e+05 1.37e-09  1.08e+05     2s
#   33   1.14068307e+10  3.71354052e+09  9.31e+04 9.24e-14  6.52e+04     2s
#   34   1.09099436e+10  5.12513161e+09  6.22e+04 2.55e-10  4.84e+04     2s
#   35   1.08596464e+10  5.42898302e+09  5.83e+04 1.82e-11  4.54e+04     2s
#   36   1.06810219e+10  6.43424773e+09  4.70e+04 1.08e-13  3.56e+04     2s
#   37   1.05605531e+10  6.61283089e+09  3.90e+04 1.07e-13  3.27e+04     2s
#   38   1.04108439e+10  6.98123443e+09  2.27e+04 9.82e-11  2.76e+04     3s
#   39   1.02261820e+10  7.48980238e+09  1.24e+04 1.07e-13  2.16e+04     3s
#   40   1.02130561e+10  7.73521868e+09  1.13e+04 3.93e-10  1.95e+04     3s
#   41   1.01942570e+10  7.80145620e+09  9.23e+03 1.21e-10  1.87e+04     3s
#   42   1.01561767e+10  8.18483506e+09  7.77e+03 3.18e-10  1.54e+04     3s
#   43   1.01532927e+10  8.35792057e+09  7.65e+03 8.50e-11  1.41e+04     3s
#   44   1.01032279e+10  8.66554770e+09  5.40e+03 1.73e-10  1.12e+04     3s
#   45   1.00970377e+10  8.72487839e+09  5.11e+03 1.36e-11  1.07e+04     3s
#   46   1.00829841e+10  8.85671570e+09  4.33e+03 1.36e-10  9.55e+03     3s
#   47   1.00710378e+10  8.88708375e+09  3.55e+03 1.59e-10  9.18e+03     3s
#   48   1.00422961e+10  9.10554995e+09  1.05e+03 9.37e-11  7.14e+03     3s
#   49   1.00291290e+10  9.28139226e+09  6.32e+02 4.14e-10  5.68e+03     3s
#   50   1.00220909e+10  9.61821835e+09  4.12e+02 1.02e-13  3.06e+03     3s
#   51   1.00152926e+10  9.76292799e+09  2.03e+02 3.42e-10  1.91e+03     3s
#   52   1.00149922e+10  9.80768225e+09  1.94e+02 9.87e-11  1.57e+03     3s
#   53   1.00098160e+10  9.92883092e+09  4.91e+01 3.91e-11  6.12e+02     4s
#   54   1.00070019e+10  9.94413625e+09  4.28e-04 1.21e-10  4.74e+02     4s
#   55   1.00064630e+10  9.99896414e+09  1.66e-04 1.54e-13  5.66e+01     4s
#   56   1.00062488e+10  1.00047671e+10  7.84e-05 2.95e-07  1.12e+01     4s
#   57   1.00060905e+10  1.00053599e+10  3.93e-05 2.54e-07  5.53e+00     4s
#   58   1.00060507e+10  1.00057500e+10  3.08e-05 7.19e-07  2.37e+00     4s
#   59   1.00059106e+10  1.00058496e+10  4.20e-06 1.13e-06  6.29e-01     4s
#   60   1.00058900e+10  1.00059023e+10  7.54e-07 1.37e-06  1.06e-01     4s
#   61   1.00058877e+10  1.00059082e+10  5.21e-07 8.57e-07  5.85e-02     4s
#
# Barrier solved model in 61 iterations and 4.07 seconds (1.80 work units)
# Optimal objective 1.00058877e+10
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 78843 primals, 166446 duals
# Objective: 1.00e+10
# Solver model: available
# Solver message: 2
# PyPSA Network
# Components:
#  - Bus: 1
#  - Carrier: 3
#  - Generator: 2
#  - Load: 1
#  - StorageUnit: 2
# Snapshots: 8760

# %%
n.generators_t.p.sum()
# Out:
# Generator
# wind     9.999996e+02
# solar    1.320276e+08
# dtype: float64

# %%
plot_hydro_operation(n,
                     df,
                     hydro_inflow,
                     freq='m'
                    )
